# %%
from sympy.matrices import Matrix
from sympy import exp, pi, simplify
import numpy as np

X = Matrix([[0,1], [1,0]])

simplify(simplify(exp(-1.0j*X*pi/4)))
# Out:
# Matrix([
# [0.707106781186547 + 5.55111512312578e-17*I,                       -0.707106781186547*I],
# [                      -0.707106781186547*I, 0.707106781186547 + 5.55111512312578e-17*I]])

# %%
from sympy import symbols, exp, I, solve

alpha, beta, t = symbols('a b t')
X = Matrix([[0,1], [1,0]])
Z = Matrix([[1,0], [0,-1]])

ham = alpha *X + beta*Z

u = exp(-I*ham)

# %%
solve(u[0,0], alpha, beta)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /home/raul/Projects/TUE-project-notes/calcs/calcs.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/home/raul/Projects/TUE-project-notes/calcs/calcs.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> solve(u[0,0], alpha, beta)
#
# File ~/.local/share/virtualenvs/TUE-project-notes-c7Ad79Rx/lib/python3.11/site-packages/sympy/solvers/solvers.py:1145, in solve(f, *symbols, **flags)
#    1143         solution = _solve_undetermined(f[0], symbols, flags)
#    1144     if not solution:
# -> 1145         solution = _solve(f[0], *symbols, **flags)
#    1146 else:
#    1147     linear, solution = _solve_system(f, symbols, **flags)
#
# File ~/.local/share/virtualenvs/TUE-project-notes-c7Ad79Rx/lib/python3.11/site-packages/sympy/solvers/solvers.py:1352, in _solve(f, *symbols, **flags)
#    1350         return result
#    1351     else:
# ...

# %%
solve?
# Out:
# Signature: solve(f, *symbols, **flags)
# Docstring:
# Algebraically solves equations and systems of equations.
#
# Explanation
# ...
#
# Currently supported:
#     - polynomial
#     - transcendental
#     - piecewise combinations of the above
#     - systems of linear and polynomial equations
#     - systems containing relational expressions
#     - systems implied by undetermined coefficients
#
# Examples
# ...
#
# The default output varies according to the input and might
# be a list (possibly empty), a dictionary, a list of
# dictionaries or tuples, or an expression involving relationals.
# For specifics regarding different forms of output that may appear, see :ref:`solve_output`.
# Let it suffice here to say that to obtain a uniform output from
# `solve` use ``dict=True`` or ``set=True`` (see below).
#
#     >>> from sympy import solve, Poly, Eq, Matrix, Symbol
#     >>> from sympy.abc import x, y, z, a, b
#
# The expressions that are passed can be Expr, Equality, or Poly
# ...
